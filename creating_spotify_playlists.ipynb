# %%
#pip install spotipy --upgrade

# %%
import spotipy
import pandas as pd
from spotipy.oauth2 import SpotifyOAuth
import json

# %%
songs=pd.read_csv("C:/Users/sarra/Downloads/songs1.csv")

# %%
songs
# Out:
#                                                    name
# 0     Se Eu Quiser Falar Com Deus                   ...  \
# 1     Saudade De Bahia                              ...
# 2     Canta Canta, Minha Gente                      ...
# 3     Mulher Eu Sei                                 ...
# 4     Rosa Morena                                   ...
# ...                                                 ...
# 5230  1812 Festival Overture, Op. 49: 1812 Overture,...
# 5231  Winter Fragments pour ensemble instrumental, s...
# 5232  Schoenberg: 5 Orchestral Pieces, Op. 16: No. 3...
# 5233  Serenade For Strings In E, Op.22, B. 52: 1. Mo...
# 5234  Ravel: Boléro, M. 81                          ...
#
#                                                 artist  danceability   energy
# 0     Gilberto Gil                                            0.6580  0.25900  \
# 1     Antônio Carlos Jobim                                    0.7420  0.39900
# 2     Martinho Da Vila                                        0.8510  0.73000
# 3     Chico César                                             0.7050  0.05020
# 4     Kurt Elling                                             0.6510  0.11900
# ...                                                ...           ...      ...
# 5230  Pyotr Ilyich Tchaikovsky                                0.2020  0.06940
# 5231  Tristan Murail                                          0.1880  0.10100
# 5232  Arnold Schoenberg                                       0.0596  0.00093
# 5233  Antonín Dvořák                                          0.1330  0.02080
# 5234  Maurice Ravel                                           0.3540  0.04870
#
#       key  loudness  mode  speechiness  acousticness  instrumentalness
# 0      11   -13.141     0       0.0705         0.694          0.000059  \
# 1       2   -12.646     1       0.0346         0.217          0.000002
# 2       2   -11.048     1       0.3470         0.453          0.000063
# 3       4   -18.115     1       0.0471         0.879          0.000041
# 4       6   -19.807     1       0.0380         0.916          0.000343
# ...   ...       ...   ...          ...           ...               ...
# 5230    3   -23.390     1       0.0473         0.917          0.715000
# 5231    6   -21.873     1       0.0442         0.855          0.426000
# 5232    9   -42.959     1       0.0434         0.951          0.969000
# 5233    4   -29.443     1       0.0419         0.883          0.505000
# 5234    5   -24.568     1       0.0323         0.783          0.484000
#
#       liveness  valence    tempo   type  duration_ms  time_signature
# 0       0.9750   0.3060  110.376              256213               4  \
# 1       0.1070   0.6930  125.039              191867               4
# 2       0.1240   0.9050   93.698              152267               4
# 3       0.3860   0.5240  106.802              186227               4
# 4       0.1040   0.4020  120.941              273680               4
# ...        ...      ...      ...    ...          ...             ...
# 5230    0.0832   0.0655   87.906              995000               4
# 5231    0.0694   0.0355   83.134              855000               4
# 5232    0.0772   0.0344   71.573              238187               3
# 5233    0.1110   0.0591   67.109              314307               4
# 5234    0.2840   0.2530   64.120              948787               3
#
#                            id
# 0     1n7JnwviZ7zf0LR1tcGFq7   \
# 1     5QGM1U0eCYrQuwSJwTm5Zq
# 2     0NLIFSZxPzQhCwnkn5PJYs
# 3     3mXqOdlLE1k67WsAxryPFs
# 4     7bSzjzjTkWT2CkIPPdp0eA
# ...                       ...
# 5230  1aEhYlZtypmipA06SDJ4U3
# 5231  1Gfqe7TAKklmuZf6hxsH6h
# 5232  2XNwnFrdMDpismp0VUZ7cU
# 5233  7ucDwgMtE3YJtEfTbuRhy0
# 5234  7E1ErYYCn0lYjHODZ1qGuB
#
#                                                    html  cluster
# 0     https://open.spotify.com/track/1n7JnwviZ7zf0LR...       15
# 1     https://open.spotify.com/track/5QGM1U0eCYrQuwS...        9
# 2     https://open.spotify.com/track/0NLIFSZxPzQhCwn...       14
# 3     https://open.spotify.com/track/3mXqOdlLE1k67Ws...       20
# 4     https://open.spotify.com/track/7bSzjzjTkWT2CkI...       20
# ...                                                 ...      ...
# 5230  https://open.spotify.com/track/1aEhYlZtypmipA0...        2
# 5231  https://open.spotify.com/track/1Gfqe7TAKklmuZf...        8
# 5232  https://open.spotify.com/track/2XNwnFrdMDpismp...        2
# 5233  https://open.spotify.com/track/7ucDwgMtE3YJtEf...        2
# 5234  https://open.spotify.com/track/7E1ErYYCn0lYjHO...        2
#
# [5235 rows x 19 columns]

# %%
scope = 'playlist-modify-public'
username = "31x3gtp4xyx6lvbpm4vhzycgclu4"
redirectUri = 'http://localhost:8000/callback'

token = SpotifyOAuth(scope=scope,username=username,client_id=client_id, client_secret=client_secret ,redirect_uri='http://localhost:8000/callback',)
spotifyObject = spotipy.Spotify(auth_manager = token)

# %%
playlists=[]
for i in range (21):
    playlists.append(songs[songs["cluster"]==i])

# %%
len(playlists)
# Out:
# 21

# %%
playlists[0]
# Out:
#                                                    name
# 261   Come Saturday                                 ...  \
# 335   Waterfall                                     ...
# 2333  Stinkfist                                     ...
# 2791  Dynamo - Original Mix                         ...
# 2792  Spank - Radio Edit                            ...
# ...                                                 ...
# 4485  The Exorcist                                  ...
# 4489  Stench of Prophet                             ...
# 4492  Warriors Trial                                ...
# 4499  Infection Of Death                            ...
# 4500  Mutant Christ                                 ...
#
#                                                 artist  danceability  energy
# 261   The Pains Of Being Pure At Heart                         0.163   0.938  \
# 335   The Fresh & Onlys                                        0.219   0.906
# 2333  TOOL                                                     0.286   0.728
# 2791  Laidback Luke                                            0.644   0.906
# 2792  The Bloody Beetroots                                     0.499   0.923
# ...                                                ...           ...     ...
# 4485  Cannibal Corpse                                          0.117   0.950
# 4489  Brutal Truth                                             0.194   0.964
# 4492  Amorphis                                                 0.166   0.950
# 4499  Baphomet                                                 0.240   0.834
# 4500  Cryptopsy                                                0.179   0.954
#
#       key  loudness  mode  speechiness  acousticness  instrumentalness
# 261     6    -5.071     0       0.0716      0.000002             0.941  \
# 335     4    -4.995     1       0.0392      0.078000             0.852
# 2333    0    -6.608     1       0.0616      0.000174             0.836
# 2791    0    -2.981     1       0.0805      0.003930             0.945
# 2792    9    -3.638     1       0.0601      0.002190             0.757
# ...   ...       ...   ...          ...           ...               ...
# 4485    6    -9.237     0       0.0842      0.000016             0.947
# 4489    6   -14.119     0       0.0658      0.000001             0.942
# 4492    5    -4.894     1       0.0810      0.000012             0.840
# 4499    6   -10.033     0       0.0866      0.000761             0.891
# 4500    6   -14.625     1       0.0538      0.000112             0.870
#
#       liveness  valence    tempo   type  duration_ms  time_signature
# 261     0.2880   0.4910  180.248              197267               4  \
# 335     0.2650   0.6020  198.232              161156               4
# 2333    0.1330   0.4670  171.441              312120               4
# 2791    0.1950   0.0976  129.001              279080               4
# 2792    0.1980   0.2040  129.033              223320               4
# ...        ...      ...      ...    ...          ...             ...
# 4485    0.1430   0.3630  186.589              276893               4
# 4489    0.0747   0.0630  133.358               82400               5
# 4492    0.0806   0.1080  148.158              304733               4
# 4499    0.1320   0.2750  178.744              203053               3
# 4500    0.1850   0.1590  156.100              261160               4
#
#                            id
# 261   3LiJkn24zLD0SUPbVNyDwh   \
# 335   3soRnznKdQHTMmuW6wiUDY
# 2333  0pwObEOHolQZSldJ2q1wpy
# 2791  0UKduoI2FVN62F0jA8S3kQ
# 2792  22Yf6IsqqAiiRA6UBrMxos
# ...                       ...
# 4485  4Yol1lMkRgZDfeTGqHans2
# 4489  6b2pUMt6tQVEI2JThxeZfY
# 4492  0Lgpj2BfgNp4EJfk39Mjx7
# 4499  7LQVMOFYTaSa3j5Ozft6cB
# 4500  0RspwvCRbt6Ce6L4LEbR6t
#
#                                                    html  cluster
# 261   https://open.spotify.com/track/3LiJkn24zLD0SUP...        0
# 335   https://open.spotify.com/track/3soRnznKdQHTMmu...        0
# 2333  https://open.spotify.com/track/0pwObEOHolQZSld...        0
# 2791  https://open.spotify.com/track/0UKduoI2FVN62F0...        0
# 2792  https://open.spotify.com/track/22Yf6IsqqAiiRA6...        0
# ...                                                 ...      ...
# 4485  https://open.spotify.com/track/4Yol1lMkRgZDfeT...        0
# 4489  https://open.spotify.com/track/6b2pUMt6tQVEI2J...        0
# 4492  https://open.spotify.com/track/0Lgpj2BfgNp4EJf...        0
# 4499  https://open.spotify.com/track/7LQVMOFYTaSa3j5...        0
# 4500  https://open.spotify.com/track/0RspwvCRbt6Ce6L...        0
#
# [194 rows x 19 columns]

# %%
import itertools

for i, playlist in enumerate(playlists):
    playlist_name = f'Playlist_{i}'
    playlist_description = ''
    playlist_id = spotifyObject.user_playlist_create(user=username, name=playlist_name, public=True, description=playlist_description)['id']
    list_of_songs = []
    for index, song in playlist.iterrows():
        result = spotifyObject.search(q=f"{song['name']} artist:{song['artist']}", type='track', limit=1)
        try:
            list_of_songs.append(result['tracks']['items'][0]['id'])
        except IndexError:
            continue

    track_chunks = list(itertools.islice(list_of_songs, 100))
    spotifyObject.user_playlist_add_tracks(user=username, playlist_id=playlist_id, tracks=track_chunks)
